# %%
def calculator():
        print("Simple Calculator")
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))
        print("Select operation:")
        print("1. Add")
        print("2. Divide")
        choice = input("Enter choice (1/2):")
        if choice =='1':
             print(f"Result: {num1} + {num2}={num1 + num2}")
        elif choice =='2':
            if num2 != 0:
             print(f"Result: {num1} / {num2}={num1 / num2}")
            else:
                print("Error! Division by zero.") 
        else:
         print("Invalid Input") 
calculator()
# Out:
# Simple Calculator
# Select operation:
# 1. Add
# 2. Divide
# Result: 12.0 + 1.0=13.0

# %%
def temperature_converter():
    print("Temperature Converter")
    temp = float(input("Enter temperature: "))
    print("Convert to:")
    print("1. Celsius to Fahrenheit")
    print("2. Fahrenheit to Celsius")
    choice = input("Enter choice (1/2): ")
    if choice == '1':
      fahrenheit = (temp * 9/5) + 32
      print(f"{temp}°C is {fahrenheit}°F")
    elif choice == '2':
      celsius = (temp - 32) * 5/9
      print(f"{temp}°F is {celsius}°C")
    else:
      print("Invalid Input")
temperature_converter()
# Out:
# Temperature Converter
# Convert to:
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# 31.0°F is -0.5555555555555556°C

# %%
def factorial(n):
    if n == 0 or n == 1:
       return 1
    else:
       return n * factorial(n-1)

num = int(input("Enter a number to find its factorial: "))
print(f"The factorial of {num} is {factorial(num)}")
# Out:
# The factorial of 4 is 24

# %%
def word_count(sentence):
    words=sentence.split()
    return len(words)

sentence=input("Enter a sentence:")
print(f"The number of words in the sentence is: {word_count(sentence)}")
# Out:
# The number of words in the sentence is: 5

# %%
def find_largest():
    print("Find the largest of three numbers")
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))
    num3 = float(input("Enter third number: "))

    if num1 >= num2 and num1 >= num3:
     largest = num1
    elif num2 >= num1 and num2 >= num3:
     largest = num2
    else:
     largest = num3

    print(f"The largest number is: {largest}")

find_largest()
# Out:
# Find the largest of three numbers
# The largest number is: 8.0

# %%
def list_operations():
    my_list=[]
    while True:
        print("\nList Operations:")
        print("1.Insert an element")
        print("2.Delete an element")
        print("3.Find an element")
        print("4.Display list")
        print("5.Exit")
        choice=int(input("Enter your choice: "))
        if choice==1:
            element=input("Enter element to insert:")
            my_list.append(element)
            print(f"Element'{element}'inserted.")
        elif choice==2:
            element=input("Enter element to delete:")
            if element in my_list:
                my_list.remove(element)
                print(f"Element'{element}'deleted.")
            else:
                print(f"Element'{element}'not found.")    
        elif choice==3:
            element=input("Enter element to find:")
            if element in my_list: 
                print(f"Element'{element}'found.")
            else:
                print(f"Element'{element}'not found.")  
        elif choice==4:
            print(f"Current list: {my_list}")
        elif choice==5:
            break
        else:
            print("Invalid choice,please try again.")
list_operations()
# Out:
# List Operations:
# 1.Insert an element
# 2.Delete an element
# 3.Find an element
# 4.Display list
# 5.Exit
# Element'Neha'inserted.
#
# List Operations:
# 1.Insert an element
# 2.Delete an element
# 3.Find an element
# 4.Display list
# 5.Exit
# Current list: ['Neha']
#
# List Operations:
# 1.Insert an element
# 2.Delete an element
# 3.Find an element
# 4.Display list
# 5.Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 34
#      32         else:
#      33             print("Invalid choice,please try again.")
# ---> 34 list_operations()
#
# Cell In[1], line 10, in list_operations()
#       8 print("4.Display list")
#       9 print("5.Exit")
# ---> 10 choice=int(input("Enter your choice: "))
#      11 if choice==1:
#      12     element=input("Enter element to insert:")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
#list[]
#tuple()
#sets{}
#create empty set: any name=set()
#because set{} will give data type as dictionaries

# %%
arr=[2,4,6,8,10]

# %%
arr.append(3)
print(arr)
# Out:
# [2, 4, 6, 8, 10, 3]

# %%
arr.remove(3)
print(arr)
# Out:
# [2, 4, 6, 8, 10]

# %%
for i in arr:
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
def merge_dictionaries(dict1, dict2):
    merged_dict = dict1.copy() 
    merged_dict.update(dict2) 
    return merged_dict

dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}

print(f"Dictionary 1: {dict1}")
print(f"Dictionary 2: {dict2}")
merged = merge_dictionaries(dict1, dict2)
print(f"Merged Dictionary: {merged}")
# Out:
# Dictionary 1: {'a': 1, 'b': 2}
# Dictionary 2: {'c': 3, 'd': 4}
# Merged Dictionary: {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
with open('example.txt','r') as file:
    content=file.read()
    print(content)
# Out:
# Hello World!
# this is a new line.

# %%
with open('example.txt','w') as file:
    file.write('Hello World123!\n')
    file.write('this is a new line123.\n')

# %%
with open('example.txt','a') as file:
    file.write('Hello ankii!\n')

# %%
### Writing a list of lines to a file
lines=['First line \n','Second line \n','Third line\n']
with open('example.txt','a') as file:
    file.writelines(lines)

# %%
data = b'\x00\x01\x02\x03\x04'
with open('example.bin', 'wb') as file:
    file.write(data)

# %%
with open('example.bin', 'rb') as file:
    content = file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
with open('example.txt', 'r') as source_file:
    content = source_file.read()

with open('destination.txt', 'w') as destination_file:
    destination_file.write(content)

# %%
with open('example.txt','w+') as file:
    file.write("Hello world\n")
    file.write("This is a new line \n")

    file.seek(0)

    content=file.read()
    print(content)
# Out:
# Hello world
# This is a new line
