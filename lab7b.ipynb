# %%
import pandas as pd

# %%
df1=pd.read_csv(r'C:\Users\rvu\Desktop\program\7prog_6Mcd_null_values.csv')

# %%
print("\nMissing values in the DataFrame:")
print(df1.isnull().sum())
# Out:
# Missing values in the DataFrame:
# Year                          0
# McDonalds_Revenue_$Billion    0
# Growth_rate_percent           1
# Q1                            4
# Q2                            4
# Q3                            4
# Q4                            3
# dtype: int64

# %%
df1['Q1'].fillna(df1['Q1'].mean(), inplace=True)
print("\nDataFrame after filling missing values in 'Q1' column:")
df1
# Out:
# DataFrame after filling missing values in 'Q1' column:
# C:\Users\rvu\AppData\Local\Temp\ipykernel_23532\2192483125.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Q1'].fillna(df1['Q1'].mean(), inplace=True)
#     Year  McDonalds_Revenue_$Billion  Growth_rate_percent    Q1   Q2   Q3   Q4
# 0   1999                        13.3                  NaN  5.43  NaN  NaN  NaN
# 1   2000                        14.2                  7.0  5.43  NaN  NaN  NaN
# ...

# %%
print("\nMissing values in the DataFrame:")
print(df1.isnull().sum())
# Out:
# Missing values in the DataFrame:
# Year                          0
# McDonalds_Revenue_$Billion    0
# Growth_rate_percent           1
# Q1                            0
# Q2                            4
# Q3                            4
# Q4                            3
# dtype: int64

# %%
df1['Q2'].fillna(df1['Q2'].mean(), inplace=True)
print("\nDataFrame after filling missing values in 'Q2' column:")
df1
# Out:
# DataFrame after filling missing values in 'Q2' column:
# C:\Users\rvu\AppData\Local\Temp\ipykernel_23532\2924243464.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Q2'].fillna(df1['Q2'].mean(), inplace=True)
#     Year  McDonalds_Revenue_$Billion  Growth_rate_percent    Q1     Q2   Q3  \
# 0   1999                        13.3                  NaN  5.43  5.795  NaN
# 1   2000                        14.2                  7.0  5.43  5.795  NaN
# ...

# %%
print("\nMissing values in the DataFrame:")
print(df1.isnull().sum())
# Out:
# Missing values in the DataFrame:
# Year                          0
# McDonalds_Revenue_$Billion    0
# Growth_rate_percent           1
# Q1                            0
# Q2                            0
# Q3                            4
# Q4                            3
# dtype: int64

# %%
df1['Q3'].fillna(df1['Q3'].mean(), inplace=True)
print("\nDataFrame after filling missing values in 'Q3' column:")
df1
# Out:
# DataFrame after filling missing values in 'Q3' column:
# C:\Users\rvu\AppData\Local\Temp\ipykernel_23532\1076317282.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Q3'].fillna(df1['Q3'].mean(), inplace=True)
#     Year  McDonalds_Revenue_$Billion  Growth_rate_percent    Q1     Q2     Q3  \
# 0   1999                        13.3                  NaN  5.43  5.795  6.035
# 1   2000                        14.2                  7.0  5.43  5.795  6.035
# ...

# %%
print("\nMissing values in the DataFrame:")
print(df1.isnull().sum())
# Out:
# Missing values in the DataFrame:
# Year                          0
# McDonalds_Revenue_$Billion    0
# Growth_rate_percent           1
# Q1                            0
# Q2                            0
# Q3                            0
# Q4                            3
# dtype: int64

# %%
df1['Q4'].fillna(df1['Q4'].mean(), inplace=True)
print("\nDataFrame after filling missing values in 'Q4' column:")
df1
# Out:
# DataFrame after filling missing values in 'Q4' column:
# C:\Users\rvu\AppData\Local\Temp\ipykernel_23532\2697065869.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Q4'].fillna(df1['Q4'].mean(), inplace=True)
#     Year  McDonalds_Revenue_$Billion  Growth_rate_percent    Q1     Q2     Q3  \
# 0   1999                        13.3                  NaN  5.43  5.795  6.035
# 1   2000                        14.2                  7.0  5.43  5.795  6.035
# ...
